# %% [markdown]
# <a href="https://colab.research.google.com/github/Chandanlokesh/python-lab/blob/master/prog10.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#10 Write a Python program to demonstrate Time series analysis with Pandas.


import pandas as pd
import numpy as np
import matplotlib.pyplot as plt


# Generate a date range
date_range = pd.date_range(start='2024-01-01', periods=100, freq='D')
print(date_range)
# Create a synthetic time series dataset
data = {
   'Date': date_range,
   'Value': np.cumsum(np.random.randn(100))  # Cumulative sum of random values
}
df = pd.DataFrame(data)
print(df)
df.set_index('Date', inplace=True)


# Display the first few rows of the dataset
print("First 5 rows of the dataset:")
print(df.head())


# Plot the time series
df.plot(figsize=(10, 5), title='Time Series Data')
plt.xlabel('Date')
plt.ylabel('Value')
plt.grid()
plt.show()


# Perform basic statistics
print("\nBasic Statistics:")
print(df.describe())


# Rolling mean (7-day window)
df['Rolling Mean'] = df['Value'].rolling(window=7).mean()


# Plot the rolling mean
df[['Value', 'Rolling Mean']].plot(figsize=(10, 5), title='Time Series with Rolling Mean')
plt.xlabel('Date')
plt.ylabel('Value')
plt.grid()
plt.show()


# Resampling (Monthly mean)
df_resampled = df.resample('M').mean()
print("\nResampled Monthly Mean:")
print(df_resampled)
# Out:
# DatetimeIndex(['2024-01-01', '2024-01-02', '2024-01-03', '2024-01-04',
#                '2024-01-05', '2024-01-06', '2024-01-07', '2024-01-08',
#                '2024-01-09', '2024-01-10', '2024-01-11', '2024-01-12',
#                '2024-01-13', '2024-01-14', '2024-01-15', '2024-01-16',
#                '2024-01-17', '2024-01-18', '2024-01-19', '2024-01-20',
#                '2024-01-21', '2024-01-22', '2024-01-23', '2024-01-24',
#                '2024-01-25', '2024-01-26', '2024-01-27', '2024-01-28',
#                '2024-01-29', '2024-01-30', '2024-01-31', '2024-02-01',
#                '2024-02-02', '2024-02-03', '2024-02-04', '2024-02-05',
#                '2024-02-06', '2024-02-07', '2024-02-08', '2024-02-09',
#                '2024-02-10', '2024-02-11', '2024-02-12', '2024-02-13',
#                '2024-02-14', '2024-02-15', '2024-02-16', '2024-02-17',
#                '2024-02-18', '2024-02-19', '2024-02-20', '2024-02-21',
#                '2024-02-22', '2024-02-23', '2024-02-24', '2024-02-25',
#                '2024-02-26', '2024-02-27', '2024-02-28', '2024-02-29',
#                '2024-03-01', '2024-03-02', '2024-03-03', '2024-03-04',
#                '2024-03-05', '2024-03-06', '2024-03-07', '2024-03-08',
#                '2024-03-09', '2024-03-10', '2024-03-11', '2024-03-12',
#                '2024-03-13', '2024-03-14', '2024-03-15', '2024-03-16',
#                '2024-03-17', '2024-03-18', '2024-03-19', '2024-03-20',
#                '2024-03-21', '2024-03-22', '2024-03-23', '2024-03-24',
#                '2024-03-25', '2024-03-26', '2024-03-27', '2024-03-28',
#                '2024-03-29', '2024-03-30', '2024-03-31', '2024-04-01',
#                '2024-04-02', '2024-04-03', '2024-04-04', '2024-04-05',
#                '2024-04-06', '2024-04-07', '2024-04-08', '2024-04-09'],
#               dtype='datetime64[ns]', freq='D')
#          Date     Value
# 0  2024-01-01 -2.552990
# 1  2024-01-02 -1.899371
# 2  2024-01-03 -1.034935
# 3  2024-01-04 -1.777100
# 4  2024-01-05  0.492655
# ..        ...       ...
# 95 2024-04-05  2.198190
# 96 2024-04-06  3.145442
# 97 2024-04-07  2.990432
# 98 2024-04-08  3.604511
# 99 2024-04-09  4.526718
#
# [100 rows x 2 columns]
# First 5 rows of the dataset:
#                Value
# Date
# 2024-01-01 -2.552990
# 2024-01-02 -1.899371
# 2024-01-03 -1.034935
# 2024-01-04 -1.777100
# 2024-01-05  0.492655
# Basic Statistics:
#             Value
# count  100.000000
# mean    -5.450422
# std      5.323967
# min    -15.164979
# 25%    -10.587353
# 50%     -5.391994
# 75%     -0.950271
# max      4.526718
# Resampled Monthly Mean:
#                Value  Rolling Mean
# Date
# 2024-01-31 -0.872105     -0.393198
# 2024-02-29 -9.752526     -8.790884
# 2024-03-31 -8.228289     -9.258584
# 2024-04-30  2.210370      0.143905
# <ipython-input-7-fb5372dbc100>:53: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   df_resampled = df.resample('M').mean()
